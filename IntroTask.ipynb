# %% [markdown]
# ### Intro Task Notebook
# In this notebook I use scipy curve_fit to fit the linear data provided to me by Dr. Rudnick. First the data is called using np.loadtxt then the data is fitted using curve_fit.

# %%
import FittingModule as fm
fm.fitter("Data.txt")
# Out:
# a= 5.864784569618574 +/- 0.44774316438927997
# b= 37.154170813198974 +/- 10.14610117551506
